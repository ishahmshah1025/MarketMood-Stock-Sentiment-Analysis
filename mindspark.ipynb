# %% [markdown]
# <a href="https://colab.research.google.com/github/ishahmshah1025/Mindspark-24/blob/main/mindspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance nltk requests
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.44)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.5)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)

# %%
import yfinance as yf
import requests
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

# Download VADER for sentiment analysis
nltk.download('vader_lexicon')

# Function to fetch stock data
def fetch_stock_data(ticker):
    stock = yf.Ticker(ticker)
    data = stock.history(period='5d')  # Fetch the last 5 days of data
    return data

# Function to fetch news headlines (placeholder function)
def fetch_news_headlines(ticker):
    # In practice, you would replace this with actual news fetching logic
    # For now, we are using static headlines for demonstration
    return [
        f"{ticker} stock rallies after earnings report.",
        f"Analysts predict a downturn for {ticker} in the coming months.",
        f"{ticker} faces legal challenges over patent issues.",
        f"Market response to {ticker}'s latest product launch is overwhelmingly positive."
    ]

# Function to perform sentiment analysis
def analyze_sentiment(headlines):
    sia = SentimentIntensityAnalyzer()
    sentiments = []
    for headline in headlines:
        sentiment = sia.polarity_scores(headline)
        sentiments.append((headline, sentiment))
    return sentiments

# Main function
def main(ticker):
    # Fetch stock data
    stock_data = fetch_stock_data(ticker)
    print("Stock Data:")
    print(stock_data)

    # Fetch news headlines
    headlines = fetch_news_headlines(ticker)

    # Perform sentiment analysis
    sentiment_results = analyze_sentiment(headlines)

    print("\nSentiment Analysis Results:")
    for headline, sentiment in sentiment_results:
        print(f"Headline: {headline}, Sentiment: {sentiment}")

# Example usage
if __name__ == "__main__":
    main("AAPL")  # Replace 'AAPL' with your desired stock ticker
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# Stock Data:
#                                  Open        High         Low       Close  \
# Date
# 2024-10-11 00:00:00-04:00  229.300003  229.410004  227.339996  227.550003
# 2024-10-14 00:00:00-04:00  228.699997  231.729996  228.600006  231.300003
# 2024-10-15 00:00:00-04:00  233.610001  237.490005  232.369995  233.850006
# 2024-10-16 00:00:00-04:00  231.600006  232.119995  229.839996  231.779999
# 2024-10-17 00:00:00-04:00  233.429993  233.850006  230.520004  232.149994
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-10-11 00:00:00-04:00  31759200        0.0           0.0
# 2024-10-14 00:00:00-04:00  39882100        0.0           0.0
# 2024-10-15 00:00:00-04:00  64751400        0.0           0.0
# 2024-10-16 00:00:00-04:00  34082200        0.0           0.0
# 2024-10-17 00:00:00-04:00  32978900        0.0           0.0
#
# Sentiment Analysis Results:
# Headline: AAPL stock rallies after earnings report., Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Headline: Analysts predict a downturn for AAPL in the coming months., Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Headline: AAPL faces legal challenges over patent issues., Sentiment: {'neg': 0.0, 'neu': 0.641, 'pos': 0.359, 'compound': 0.2023}
# Headline: Market response to AAPL's latest product launch is overwhelmingly positive., Sentiment: {'neg': 0.115, 'neu': 0.611, 'pos': 0.275, 'compound': 0.4767}

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)

# %%
import yfinance as yf
import requests
from bs4 import BeautifulSoup
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

# Download VADER for sentiment analysis
nltk.download('vader_lexicon')

# Function to fetch stock data
def fetch_stock_data(ticker):
    stock = yf.Ticker(ticker)
    data = stock.history(period='5d')  # Fetch the last 5 days of data
    return data

# Function to fetch news articles from Yahoo Finance
def fetch_news_articles(ticker):
    url = f"https://finance.yahoo.com/quote/{ticker}/news?p={ticker}"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    articles = []

    for item in soup.find_all('li', class_='js-stream-content'):
        headline = item.find('h3').text
        link = item.find('a')['href']
        if not link.startswith('http'):
            link = 'https://finance.yahoo.com' + link
        articles.append((headline, link))

    return articles

# Function to fetch the content of each article
def fetch_article_content(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        paragraphs = soup.find_all('p')
        content = ' '.join([para.text for para in paragraphs])
        return content
    except Exception as e:
        print(f"Error fetching article content: {e}")
        return ""

# Function to perform sentiment analysis
def analyze_sentiment(article_contents):
    sia = SentimentIntensityAnalyzer()
    sentiments = []
    for content in article_contents:
        sentiment = sia.polarity_scores(content)
        sentiments.append(sentiment)
    return sentiments

# Main function
def main(ticker):
    # Fetch stock data
    stock_data = fetch_stock_data(ticker)
    print("Stock Data:")
    print(stock_data)

    # Fetch news articles
    articles = fetch_news_articles(ticker)

    # Fetch the content of each article
    article_contents = []
    for _, link in articles:
        content = fetch_article_content(link)
        if content:  # Only add non-empty contents
            article_contents.append(content)

    # Perform sentiment analysis
    sentiment_results = analyze_sentiment(article_contents)

    print("\nSentiment Analysis Results:")
    for (headline, _), sentiment in zip(articles, sentiment_results):
        print(f"Headline: {headline}\nSentiment: {sentiment}\n")

# Example usage
if __name__ == "__main__":
    main("AAPL")  # Replace 'AAPL' with your desired stock ticker
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Stock Data:
#                                  Open        High         Low       Close  \
# Date
# 2024-10-11 00:00:00-04:00  229.300003  229.410004  227.339996  227.550003
# 2024-10-14 00:00:00-04:00  228.699997  231.729996  228.600006  231.300003
# 2024-10-15 00:00:00-04:00  233.610001  237.490005  232.369995  233.850006
# 2024-10-16 00:00:00-04:00  231.600006  232.119995  229.839996  231.779999
# 2024-10-17 00:00:00-04:00  233.429993  233.850006  230.520004  232.149994
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-10-11 00:00:00-04:00  31759200        0.0           0.0
# 2024-10-14 00:00:00-04:00  39882100        0.0           0.0
# 2024-10-15 00:00:00-04:00  64751400        0.0           0.0
# 2024-10-16 00:00:00-04:00  34082200        0.0           0.0
# 2024-10-17 00:00:00-04:00  32978900        0.0           0.0
#
# Sentiment Analysis Results:

# %%
94a44c5e22284be1aebbe334af0ac941

# %%
import requests

url = ('https://newsapi.org/v2/everything?'
       'q=Apple&'
       'from=2024-10-18&'
       'sortBy=popularity&'
       'apiKey=94a44c5e22284be1aebbe334af0ac941')

import requests

url = ('https://newsapi.org/v2/everything?'
       'q=Apple&'
       'from=2024-10-18&'
       'sortBy=popularity&'
       'apiKey=94a44c5e22284be1aebbe334af0ac941')

response = requests.get(url)

print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %%
import requests
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

# Download VADER for sentiment analysis
nltk.download('vader_lexicon')

# Your News API key
API_KEY = '94a44c5e22284be1aebbe334af0ac941'  # Replace with your actual News API key

# Function to fetch news articles from News API
def fetch_news_articles(ticker):
    url = f'https://newsapi.org/v2/everything?q={ticker}&apiKey={API_KEY}'
    response = requests.get(url)
    if response.status_code == 200:
        articles = response.json().get('articles', [])
        return articles
    else:
        print(f"Error fetching news: {response.status_code}")
        return []

# Function to perform sentiment analysis
def analyze_sentiment(articles):
    sia = SentimentIntensityAnalyzer()
    sentiments = []
    for article in articles:
        title = article.get('title', '')
        description = article.get('description', '')

        # Ensure both title and description are strings
        content = (title if title else '') + ' ' + (description if description else '')
        sentiment = sia.polarity_scores(content)
        sentiments.append((title, sentiment))
    return sentiments

# Main function
def main(ticker):
    # Fetch news articles
    articles = fetch_news_articles(ticker)

    if not articles:
        print("No articles found.")
        return

    # Perform sentiment analysis
    sentiment_results = analyze_sentiment(articles)

    print("\nSentiment Analysis Results:")
    for title, sentiment in sentiment_results:
        print(f"Title: {title}\nSentiment: {sentiment}\n")

# Example usage
if __name__ == "__main__":
    main("AAPL")  # Replace 'AAPL' with your desired stock ticker
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Sentiment Analysis Results:
# Title: The iPhone 16 is on shelves, but what is consumer demand indicating?
# Sentiment: {'neg': 0.046, 'neu': 0.954, 'pos': 0.0, 'compound': -0.1901}
#
# Title: Tim Cook sells $50M worth of AAPL shares, but the timing is coincidental
# Sentiment: {'neg': 0.052, 'neu': 0.749, 'pos': 0.199, 'compound': 0.8126}
#
# Title: AAPL earnings call on October 31 will include early iPhone 16 sales
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Apple has finally dropped iOS 18. Here's what's changed
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Apple is losing out to Huawei in China. Here's why
# Sentiment: {'neg': 0.067, 'neu': 0.933, 'pos': 0.0, 'compound': -0.3818}
#
# Title: Apple iPhone 16 demand is so weak employees can already buy it on discount
# Sentiment: {'neg': 0.144, 'neu': 0.675, 'pos': 0.182, 'compound': 0.4357}
#
# Title: Amazon Prime Video will soon have Apple TV+ because streaming is just cable now
# Sentiment: {'neg': 0.0, 'neu': 0.959, 'pos': 0.041, 'compound': 0.1779}
#
# Title: Resellers are hiking prices on Huawei's 'trifold' smartphone before it's even out
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Apple's iPhone 16 is in stores now — but it's missing a key selling point
# Sentiment: {'neg': 0.1, 'neu': 0.789, 'pos': 0.111, 'compound': 0.1531}
#
# Title: Sam Altman and former Apple executives are making an AI device
# Sentiment: {'neg': 0.0, 'neu': 0.934, 'pos': 0.066, 'compound': 0.4767}
#
# Title: Oura just launched its latest smart ring. Apple and Samsung are coming for it
# Sentiment: {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.7506}
#
# Title: Apple is being accused of ‘illegally’ violating workers rights by the U.S. labor board
# Sentiment: {'neg': 0.238, 'neu': 0.715, 'pos': 0.046, 'compound': -0.9022}
#
# Title: IPhone 16 Off To A Rocky Start. What It Means For Apple Stock.
# Sentiment: {'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'compound': 0.3818}
#
# Title: The S&P 500 is almost never this expensive. It’s a disaster waiting to happen.
# Sentiment: {'neg': 0.204, 'neu': 0.796, 'pos': 0.0, 'compound': -0.6249}
#
# Title: Direxion Daily AAPL Bull 2X Shares (NASDAQ:AAPU) Short Interest Down 41.7% in September
# Sentiment: {'neg': 0.06, 'neu': 0.644, 'pos': 0.296, 'compound': 0.9382}
#
# Title: Nvidia and 6 other firms that could get in on OpenAI's next big funding round
# Sentiment: {'neg': 0.041, 'neu': 0.857, 'pos': 0.102, 'compound': 0.5106}
#
# Title: Market Clubhouse Morning Memo - September 26th, 2024 (Trade Strategy For SPY, QQQ, AAPL, MSFT, NVDA, GOOGL, META And TSLA)
# Sentiment: {'neg': 0.0, 'neu': 0.883, 'pos': 0.117, 'compound': 0.7424}
#
# Title: Market Clubhouse Morning Memo - September 17th, 2024 (Trade Strategy For SPY, QQQ, AAPL, MSFT, NVDA, GOOGL, META And TSLA)
# Sentiment: {'neg': 0.0, 'neu': 0.883, 'pos': 0.117, 'compound': 0.7424}
#
# Title: Nvidia's stock surge sent its market cap past Microsoft's and close to a record high
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Amazon's next Prime Day is coming fast
# Sentiment: {'neg': 0.0, 'neu': 0.873, 'pos': 0.127, 'compound': 0.6597}
#
# Title: OpenAI is now worth more than $150 billion
# Sentiment: {'neg': 0.0, 'neu': 0.757, 'pos': 0.243, 'compound': 0.7506}
#
# Title: TSMC reports earnings tomorrow. Here's what to expect
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: エヌビディアの株価はこれから本当に上がるのか 長期のテクニカル分析で今後の値動きがわかる | 市場観測 | 東洋経済オンライン
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Why Arm Holdings Stock Lost 5% on Tuesday
# Sentiment: {'neg': 0.135, 'neu': 0.718, 'pos': 0.147, 'compound': 0.1779}
#
# Title: Do Vanguard, BlackRock & State Street Run the World?
# Sentiment: {'neg': 0.0, 'neu': 0.964, 'pos': 0.036, 'compound': 0.2869}
#
# Title: Taiwan Semiconductor (TSM) Price Prediction and Forecast
# Sentiment: {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'compound': 0.6486}
#
# Title: Prediction: 3 Stocks That'll Be Worth More Than Apple 5 Years From Now
# Sentiment: {'neg': 0.042, 'neu': 0.932, 'pos': 0.026, 'compound': -0.2263}
#
# Title: My Favorite "Magnificent Seven" Stocks to Buy Now (Hint: Nvidia's Not One)
# Sentiment: {'neg': 0.0, 'neu': 0.813, 'pos': 0.187, 'compound': 0.8957}
#
# Title: Was Brad Gerstner Wrong About Apple’s (AAPL) AI Potential?
# Sentiment: {'neg': 0.076, 'neu': 0.807, 'pos': 0.117, 'compound': 0.1779}
#
# Title: Warren Buffett Sold Half of Apple (AAPL) Shares in Q3
# Sentiment: {'neg': 0.0, 'neu': 0.804, 'pos': 0.196, 'compound': 0.296}
#
# Title: Apple (AAPL)’s Q2 Relative Performance Dropped Despite Gains
# Sentiment: {'neg': 0.066, 'neu': 0.849, 'pos': 0.085, 'compound': 0.1441}
#
# Title: Nvidia stock falls over 4% on news that U.S. could cap exports
# Sentiment: {'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'compound': 0.296}
#
# Title: The Dow drops 300 points as October starts with a port strike and a cautious Fed
# Sentiment: {'neg': 0.103, 'neu': 0.849, 'pos': 0.048, 'compound': -0.1045}
#
# Title: The Dow spikes over 300 points as all eyes are on the Fed minutes and inflation report
# Sentiment: {'neg': 0.019, 'neu': 0.981, 'pos': 0.0, 'compound': -0.0258}
#
# Title: TSMC is making chips for Apple in the U.S.
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: DOJ hits Visa with antitrust lawsuit over monopoly concerns
# Sentiment: {'neg': 0.131, 'neu': 0.777, 'pos': 0.092, 'compound': -0.296}
#
# Title: Which Big Tech Giant Offers The Best Stock Opportunity – AAPL, GOOGL, or MSFT?
# Sentiment: {'neg': 0.0, 'neu': 0.825, 'pos': 0.175, 'compound': 0.7906}
#
# Title: Why Apple's iPhone 16 just is 'not hitting home' with consumers
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Apple still AI winner despite iPhone 16 reception: Analyst
# Sentiment: {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'compound': 0.5859}
#
# Title: Apple's iPhone 16 is in stores now — but it's missing a key selling point
# Sentiment: {'neg': 0.121, 'neu': 0.799, 'pos': 0.08, 'compound': -0.2263}
#
# Title: Apple Inc. (AAPL): Among the Best Fortune 500 Stocks to Buy Now
# Sentiment: {'neg': 0.0, 'neu': 0.819, 'pos': 0.181, 'compound': 0.8555}
#
# Title: Apple Inc. (AAPL): One of the Most Widely Held Stocks by Hedge Funds
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: New Apple Inc. (AAPL) Event Planned for October to Unveil AI-Enhanced Macs
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Apple Inc. (AAPL): Wall Street Analysts Have Bullish Views On This Trending AI Stock
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Analysts Note an ‘Unexpected’ Positive Development on Apple (AAPL) iPhone 16 Demand Trends
# Sentiment: {'neg': 0.034, 'neu': 0.843, 'pos': 0.123, 'compound': 0.5994}
#
# Title: Is Apple Inc. (AAPL) the Best AI Data Center Stock to Buy Now?
# Sentiment: {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.6369}
#
# Title: Apple Inc. (AAPL): Most Promising Growth Stock According to Hedge Funds
# Sentiment: {'neg': 0.0, 'neu': 0.605, 'pos': 0.395, 'compound': 0.707}
#
# Title: Apple Inc. (AAPL): Piper Sandler Maintains Neutral Rating, Teen Survey Shows Moderate Upgrade Expectations
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Today in Apple history: Apple stock smashes through $700 barrier
# Sentiment: {'neg': 0.034, 'neu': 0.889, 'pos': 0.077, 'compound': 0.4391}
#
# Title: A PayPal and Apple Pay rival from the big banks is aiming big
# Sentiment: {'neg': 0.091, 'neu': 0.841, 'pos': 0.067, 'compound': 0.0}
#
# Title: Danish PM shrugs off risks of Ozempic maker’s economic dominance
# Sentiment: {'neg': 0.08, 'neu': 0.884, 'pos': 0.036, 'compound': -0.296}
#
# Title: Mag 7 Become Drag 7, Taking Down QQQ & Create Opening For “Q Killers”
# Sentiment: {'neg': 0.093, 'neu': 0.809, 'pos': 0.098, 'compound': 0.0516}
#
# Title: Apple Inc. (AAPL) Maintains Buy Rating at Bank of America, Initial iPhone 16 Demand Lower Due to AI Feature Delay
# Sentiment: {'neg': 0.119, 'neu': 0.852, 'pos': 0.029, 'compound': -0.5508}
#
# Title: Trick or Treat? Apple's First Earnings Call Since iPhone 16 Launch Scheduled for Halloween
# Sentiment: {'neg': 0.021, 'neu': 0.933, 'pos': 0.047, 'compound': 0.3612}
#
# Title: After The Fed Rate Cut: Soft Landing Checklist
# Sentiment: {'neg': 0.264, 'neu': 0.649, 'pos': 0.087, 'compound': -0.6597}
#
# Title: Robust Job Gains Remove Recession Fears
# Sentiment: {'neg': 0.254, 'neu': 0.61, 'pos': 0.137, 'compound': -0.5859}
#
# Title: Google to begin organizing some search results using AI, bringing ads to AI Overviews
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Bank of America Maintains Buy Rating on Apple Inc. (AAPL) with $256 Price Target, Highlights Revenue Potential from AI Integration and Services Strategy
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Apple Inc. (AAPL) Expected to Unveil Next-Gen Vision Pro Headset Powered by M5 Chip in 2025, Says Analyst Ming-Chi Kuo
# Sentiment: {'neg': 0.046, 'neu': 0.913, 'pos': 0.041, 'compound': -0.0516}
#
# Title: Apple Inc. (AAPL) Named Citi’s Top AI Stock Pick for 2025 Amid Positive Feedback on iOS 18 and Potential OpenAI Investment
# Sentiment: {'neg': 0.0, 'neu': 0.779, 'pos': 0.221, 'compound': 0.6597}
#
# Title: Apple May Have Cut iPhone 16 Builds By 3 Million. Stock Falls.
# Sentiment: {'neg': 0.135, 'neu': 0.865, 'pos': 0.0, 'compound': -0.4939}
#
# Title: Jim Cramer on Apple Inc. (AAPL): ‘I Always Say To Own It, Don’t Trade It, And I’m Even More Adamant About That Position’
# Sentiment: {'neg': 0.037, 'neu': 0.89, 'pos': 0.073, 'compound': 0.4767}
#
# Title: Apple Inc. (AAPL) Set to Launch iOS 18.1 and Apple Intelligence, Shifting from Annual Upgrade Cycle Amid Concerns Over iPhone Demand
# Sentiment: {'neg': 0.064, 'neu': 0.805, 'pos': 0.131, 'compound': 0.3818}
#
# Title: Is The iPhone Losing Its Buzz Among Teens? Piper Sandler Finds Out
# Sentiment: {'neg': 0.075, 'neu': 0.925, 'pos': 0.0, 'compound': -0.3818}
#
# Title: New Apple Vision Pro with M5 chip on the way, says analyst Ming-Chi Kuo
# Sentiment: {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.6369}
#
# Title: Apple’s Siri integration monetization potential ‘overlooked,’ says BofA
# Sentiment: {'neg': 0.077, 'neu': 0.923, 'pos': 0.0, 'compound': -0.3818}
#
# Title: ドキュメントスキャナーScanSnap用ユーティリティ「ScanSnap Home」がバージョン2.23.0でmacOS 15 Sequoiaに対応。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Black Salt Games、フィッシングアドベンチャーゲーム「DREDGE」のMac、iPhone/iPad、Android版を12月18日にリリース。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Apple представила новый iPad mini
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Microsoft、リモートデスクトップクライアント「Remote Desktop」のデザインと名前を刷新した「Windows App for macOS/Mobile」をリリース。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: キヤノンITS、macOS 15 Sequoiaに対応した「ESET Cyber Security」を公開。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Parallels、Windows VM上のWindowsアプリでApple Intelligenceによるライティングツールをサポートした「Parallels Desktop for Mac v20.1.0」をリリース。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: 六合彩 5 號碼冧莊 521 年一遇｜董之英遲報名學界足球盼酌情處理｜港 P 息減 0.25 厘較預期早｜鄭俊弘囝囝患天使綜合症病情好轉｜9 月 20 日・Yahoo 早報
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: How PayPal's new CEO is reinventing the firm as it goes beyond payments
# Sentiment: {'neg': 0.0, 'neu': 0.947, 'pos': 0.053, 'compound': 0.2023}
#
# Title: Microsoft wants to change the way you use your PC. It needs to succeed.
# Sentiment: {'neg': 0.041, 'neu': 0.9, 'pos': 0.059, 'compound': 0.1655}
#
# Title: Usuários do iPhone 16 Pro reclamam do touchscreen
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Até a Apple acredita no iPhone falsificado; entenda
# Sentiment: {'neg': 0.093, 'neu': 0.907, 'pos': 0.0, 'compound': -0.5267}
#
# Title: macOS 15 Sequoiaをサポートした多機能メンテナンス・ユーティリティ「OnyX v4.7」がリリース。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Apple、Game Porting Toolkit 2のBeta 3でDirectX RaytracingやAVXオプションを追加。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Apple、A17 Proチップや10GbpsのUSB-Cポートを搭載し、Apple IntelligenceやApple Pencil Pro、4K60Hzディスプレイ出力に対応した「iPad mini (A17 Pro)」を10月23日より発売。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Spigen、Apple Watch Series 10に対応した保護ケース「Rugged Armor」などを発売。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Anker Japan、Amazonのポータブルスピーカー部門で1位となったコンパクトBluetoothスピーカー「Anker SoundCore 2 (USB-C充電)」のオフホワイトモデルを発売。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Anker Japan、単ポート100W出力で3ポート合計167.5W出力のカーチャージャー「Anker Nano Car Charger (167.5W, 3 Ports) with USB-C & USB-C ケーブル」を発売。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Kindle本読書の秋キャンペーンで、SBクリエイティブのコンピュータ・IT・プログラミング関連書籍が最大50%OFFセール中。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: 11 bit studios、発売が延期されていたApple Silicon Mac対応のシティサバイバルゲーム「Frostpunk 2」をMac App Storeでリリース。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: コーレル、macOS 15 Sequoiaをサポートした仮想化ソフトウェア「Parallels Desktop 20」のRetail Box 永続ライセンス版を発売。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Perplexity AI、AI検索エンジンPerplexityの公式クライアント「Perplexity for Mac」のリリースを延期。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Swiftで書き直されmacOS 15 SequoiaやiCloud同期をサポートしたMac用ウィンドウマネージャ「Magnet v3.0」がリリース。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: macOS 15 Sequoiaのリリースに伴い、近く「Microsoft 365/Office 2021,2024」でmacOS 12 Montereyのサポートが終了。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Tech Stocks Fuel Market Surge: S&P 500 and Dow Hit Record Highs
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Strong Demand for iPhone 16 Pro and Pro Max Drives Lead Times Up
# Sentiment: {'neg': 0.085, 'neu': 0.734, 'pos': 0.181, 'compound': 0.6597}
#
# Title: Parallels、WindowsアプリでAIによるライティングツールをサポートしたParallels Desktop for Mac v20.1のリリースに合わせて「Parallels Desktop 20 for Mac」の25%OFFセールを開催。
# Sentiment: {'neg': 0.0, 'neu': 0.903, 'pos': 0.097, 'compound': 0.4767}
#
# Title: カプコン、Apple Silicon MacやiPad、iPhoneに対応した「BIOHAZARD RE:2」をApp Storeで2024年内にリリース。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: macOS 15 Sequoiaではテキストエディットなどで「Control + Return/Enter」キーを押すとコンテクストメニューを表示できるように。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: 米Logitech、カスタマイズ可能なキーパッドとダイヤルを備えAdobe PhotoshopやPremiere Proなどを操作できるカスタムキーデバイス「MX Creative Console」を発表。
# Sentiment: {'neg': 0.0, 'neu': 0.686, 'pos': 0.314, 'compound': 0.8271}
#
# Title: Anker Japan、ソーラー充電やHomeBaseへのローカルストレージ保存に対応した屋外セキュリティカメラ「Eufy eufyCam S330 2-Cam Kit」を発売。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Anker Japan、USB-A/-Cや4K60Hz対応のHDMIポート、microSD/SDカードリーダーなどを備えたモニタースタンド「Anker USB-C ハブ (10-in-1, Monitor Stand)」を発売。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Apple Investors Just Got Terrible News
# Sentiment: {'neg': 0.181, 'neu': 0.819, 'pos': 0.0, 'compound': -0.4767}
#
# Title: SwiftUIやSwiftDataを採用し日本語にも対応したオープンソースのコンテキストメニュー型クリップボードマネージャー「Maccy v2.0」が正式にリリース。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: 米Cable Matters、Intel Thunderbolt認証を取得しアルミニウムコネクターと編み込みケーブルを採用した「Premium Thunderbolt 5 Cable」を発売。
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
import requests
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

# Download VADER for sentiment analysis
nltk.download('vader_lexicon')

# Your News API key
API_KEY = '94a44c5e22284be1aebbe334af0ac941'  # Replace with your actual News API key

# Function to fetch news articles from News API
def fetch_news_articles(stock_name):
    url = f'https://newsapi.org/v2/everything?q={stock_name}&apiKey={API_KEY}'
    response = requests.get(url)
    if response.status_code == 200:
        articles = response.json().get('articles', [])
        return articles
    else:
        print(f"Error fetching news: {response.status_code}")
        return []

# Function to perform sentiment analysis
def analyze_sentiment(articles):
    sia = SentimentIntensityAnalyzer()
    sentiments = []
    for article in articles:
        title = article.get('title', '')
        description = article.get('description', '')

        # Ensure both title and description are strings
        content = (title if title else '') + ' ' + (description if description else '')
        sentiment = sia.polarity_scores(content)
        sentiments.append((title, sentiment))
    return sentiments

# Main function
def main():
    stock_name = input("Enter the stock name (e.g., 'AAPL' for Apple): ").strip()

    # Fetch news articles
    articles = fetch_news_articles(stock_name)

    if not articles:
        print("No articles found.")
        return

    # Perform sentiment analysis
    sentiment_results = analyze_sentiment(articles)

    print("\nSentiment Analysis Results:")
    for title, sentiment in sentiment_results:
        print(f"Title: {title}\nSentiment: {sentiment}\n")

# Example usage
if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Enter the stock name (e.g., 'AAPL' for Apple): Tata motors
#
# Sentiment Analysis Results:
# Title: Ratan Tata, former chairman of Indian conglomerate Tata Sons, dies at age 86 in a Mumbai hospital
# Sentiment: {'neg': 0.147, 'neu': 0.853, 'pos': 0.0, 'compound': -0.7351}
#
# Title: Indian entrepreneur, industrialist, and philanthropist, Ratan Tata, dead at 86
# Sentiment: {'neg': 0.434, 'neu': 0.566, 'pos': 0.0, 'compound': -0.7845}
#
# Title: India’s Ratan Tata, the man who knew how to ‘think big and bold’
# Sentiment: {'neg': 0.0, 'neu': 0.931, 'pos': 0.069, 'compound': 0.25}
#
# Title: Ratan Tata, ‘titan’ of Indian business, dies at 86
# Sentiment: {'neg': 0.124, 'neu': 0.81, 'pos': 0.067, 'compound': -0.296}
#
# Title: Ratan Tata: India’s Icon Of Business And Branding Genius Dies At 86
# Sentiment: {'neg': 0.127, 'neu': 0.809, 'pos': 0.064, 'compound': -0.3818}
#
# Title: Ratan Tata—Ex-Leader Of India’s Massive Tata Group—Dies At 86
# Sentiment: {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.8316}
#
# Title: Tata motors chairman Ratan Tata dies aged 86
# Sentiment: {'neg': 0.045, 'neu': 0.759, 'pos': 0.197, 'compound': 0.8316}
#
# Title: È morto Ratan Tata: capo del gruppo che controlla Jaguar Land Rover
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Ratan Tata passes away at 86
# Sentiment: {'neg': 0.14, 'neu': 0.86, 'pos': 0.0, 'compound': -0.3818}
#
# Title: Starbucks, Tetley, Jaguar Land Rover: Remembering Ratan Tata's global ambitions
# Sentiment: {'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'compound': 0.2263}
#
# Title: Muere Ratan Tata, el visionario que encabezó la apertura de la economía india al mundo
# Sentiment: {'neg': 0.056, 'neu': 0.944, 'pos': 0.0, 'compound': -0.3818}
#
# Title: Omul de afaceri indian Ratan Tata, creatorul celei mai ieftine mașini din lume, a murit la vârsta de 86 de ani
# Sentiment: {'neg': 0.092, 'neu': 0.851, 'pos': 0.057, 'compound': -0.25}
#
# Title: Ratan Tata, Indian magnate who built global empire, dead at 86
# Sentiment: {'neg': 0.304, 'neu': 0.696, 'pos': 0.0, 'compound': -0.8885}
#
# Title: [Removed]
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Jaguar Land Rover to invest £500m in car plant
# Sentiment: {'neg': 0.0, 'neu': 0.924, 'pos': 0.076, 'compound': 0.2263}
#
# Title: Ratan Tata, who put India's Tata Group on global map, dies at 86
# Sentiment: {'neg': 0.142, 'neu': 0.858, 'pos': 0.0, 'compound': -0.8316}
#
# Title: Ratan Tata, who put India’s Tata Group on the global map, dies at 86
# Sentiment: {'neg': 0.119, 'neu': 0.881, 'pos': 0.0, 'compound': -0.7351}
#
# Title: BasiGo Flags Off New Tata Ultra Electric Buses In Nairobi, Strengthens Sustainable Public Transport In Kenya
# Sentiment: {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compound': 0.872}
#
# Title: [Removed]
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: What’s Driving The Son Of India’s Richest Woman To Pour Billions Into EVs?
# Sentiment: {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compound': 0.7579}
#
# Title: Tata Motors Stocks/Share Price Live Updates: Tata Motors shares trade among top gainers in Nifty 50 pack
# Sentiment: {'neg': 0.0, 'neu': 0.805, 'pos': 0.195, 'compound': 0.8834}
#
# Title: Tata Motors Stocks/Share Price Highlights October 9, 2024: Tata Motors shares end 2% higher among top gainers of Nifty 50 pack
# Sentiment: {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.8834}
#
# Title: Ratan Tata, former chairman of Indian conglomerate Tata Group, has died at age 86
# Sentiment: {'neg': 0.152, 'neu': 0.73, 'pos': 0.118, 'compound': -0.4939}
#
# Title: Ratan Tata: Πέθανε σε ηλικία 86 ετών ο Ινδός κροίσος και πρόεδρος της ομώνυμης αυτοκινητοβιομηχανίας
# Sentiment: {'neg': 0.058, 'neu': 0.942, 'pos': 0.0, 'compound': -0.3818}
#
# Title: Mukund G Rajan on Ratan Tata: A titan of our times who elevated India's stature
# Sentiment: {'neg': 0.0, 'neu': 0.743, 'pos': 0.257, 'compound': 0.8402}
#
# Title: A murit fondatorul grupului Tata, cel mai modest mogul. Conducea un autoturism ieftin, deşi avea fabrici de maşini de lux
# Sentiment: {'neg': 0.044, 'neu': 0.956, 'pos': 0.0, 'compound': -0.3818}
#
# Title: Hindistan'ın en ünlü iş insanı öldü
# Sentiment: {'neg': 0.08, 'neu': 0.92, 'pos': 0.0, 'compound': -0.3818}
#
# Title: Ινδία: Πέθανε ο Ράταν Τάτα, ο πρώην πρόεδρος του ομίλου Tata – Είχε αγοράσει τη Jaguar και τη Land Rover
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Tata Motors global wholesale declines by 11% in Q2FY25
# Sentiment: {'neg': 0.054, 'neu': 0.946, 'pos': 0.0, 'compound': -0.1531}
#
# Title: Ratan Tata, who put India's Tata Group on the global map, dies at 86
# Sentiment: {'neg': 0.138, 'neu': 0.862, 'pos': 0.0, 'compound': -0.8316}
#
# Title: Stalin lays foundation stone for Tata Motors' Rs 9,000 cr manufacturing plant in TN
# Sentiment: {'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'compound': 0.296}
#
# Title: Ratan Tata, Indian industry legend and business icon, dies aged 86
# Sentiment: {'neg': 0.081, 'neu': 0.714, 'pos': 0.205, 'compound': 0.6124}
#
# Title: Ratan Tata on kuollut
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Indian tycoon and former chairman of Tata Group dies
# Sentiment: {'neg': 0.181, 'neu': 0.819, 'pos': 0.0, 'compound': -0.7351}
#
# Title: Neutral Tata Motors, target price Rs 990: Motilal Oswal Financial Services
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Stock market update: Stocks that hit 52-week lows on NSE in today's trade
# Sentiment: {'neg': 0.13, 'neu': 0.825, 'pos': 0.045, 'compound': -0.5267}
#
# Title: Tata’s next challenge: Leadership void at Trusts
# Sentiment: {'neg': 0.065, 'neu': 0.595, 'pos': 0.34, 'compound': 0.8271}
#
# Title: Tata Motors, Tata Steel among 5 stocks with short buildup
# Sentiment: {'neg': 0.0, 'neu': 0.906, 'pos': 0.094, 'compound': 0.6369}
#
# Title: Tata Motors honors Pimpri plant workers with Diwali bonuses amid Ratan Tata’s farewell
# Sentiment: {'neg': 0.043, 'neu': 0.726, 'pos': 0.231, 'compound': 0.8519}
#
# Title: Terra Charge India、デリー政府とリライアンスグループの合弁電力事業社、BSESヤムナパワーリミテッドと業務提携開始
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Stock market update: Stocks that hit 52-week lows on NSE
# Sentiment: {'neg': 0.163, 'neu': 0.781, 'pos': 0.056, 'compound': -0.5267}
#
# Title: Tata Motors breaks ground for ₹9,000-cr high-end vehicle manufacturing unit in TN
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: How Ratan Tata acquired JLR from Ford, a decade after Ford rejected an offer to buy Tata Motors
# Sentiment: {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'compound': -0.5106}
#
# Title: Miliardarul indian Ratan Tata a murit la vârsta de 86 de ani. A fost președintele Grupului Tata, cu venituri de 100 de miliarde anual
# Sentiment: {'neg': 0.08, 'neu': 0.872, 'pos': 0.049, 'compound': -0.25}
#
# Title: Nie żyje jeden z najbogatszych ludzi świata. Stworzył marki, które zatrudniają ponad 660 tys. pracowników
# Sentiment: {'neg': 0.052, 'neu': 0.948, 'pos': 0.0, 'compound': -0.3818}
#
# Title: Tata Sons Chairman shares touching tribute to late Ratan Tata
# Sentiment: {'neg': 0.0, 'neu': 0.811, 'pos': 0.189, 'compound': 0.7845}
#
# Title: El magnate indio Ratan Tata fallece a los 86 años
# Sentiment: {'neg': 0.154, 'neu': 0.846, 'pos': 0.0, 'compound': -0.7783}
#
# Title: Tata Steel Stocks / Tata Steel Share Price Highlights September 25, 2024: Tata Steel shares trade above ₹160 mark
# Sentiment: {'neg': 0.0, 'neu': 0.783, 'pos': 0.217, 'compound': 0.8834}
#
# Title: Addio a Ratan Tata, l'ex presidente del gruppo automobilistico
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Tata Group forms alliance with Analog Devices for semiconductor manufacturing
# Sentiment: {'neg': 0.0, 'neu': 0.918, 'pos': 0.082, 'compound': 0.3818}
#
# Title: Ratan Tata over the years - I
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Hot stocks: Brokerages on Tata Motors, FirstCry and Exide
# Sentiment: {'neg': 0.043, 'neu': 0.88, 'pos': 0.077, 'compound': 0.3818}
#
# Title: Stock market update: Stocks that hit 52-week lows on NSE in today's trade
# Sentiment: {'neg': 0.144, 'neu': 0.806, 'pos': 0.05, 'compound': -0.5267}
#
# Title: Ratan Tata years: Profit zoomed 51 times, market capitalization 33 times under his leadership
# Sentiment: {'neg': 0.041, 'neu': 0.828, 'pos': 0.131, 'compound': 0.6808}
#
# Title: The titan who rebuilt Tata: Ratan Tata was as much about cleaning up the group as he was about taking it to new scales
# Sentiment: {'neg': 0.0, 'neu': 0.893, 'pos': 0.107, 'compound': 0.7269}
#
# Title: Hyundai India's record $3.3 billion IPO subscribed 18% on first day of bidding
# Sentiment: {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.6808}
#
# Title: Ratan Tata, former Tata Group chairman, dies at age 86
# Sentiment: {'neg': 0.159, 'neu': 0.779, 'pos': 0.062, 'compound': -0.6597}
#
# Title: Ratan Tata’s clarion call to ‘go global’
# Sentiment: {'neg': 0.0, 'neu': 0.954, 'pos': 0.046, 'compound': 0.2023}
#
# Title: Emkay Global sees Tata Motors stock rising with healthier balance sheet and valuation
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Remembering Ratan Tata and cars close to his heart beyond the Nano
# Sentiment: {'neg': 0.047, 'neu': 0.917, 'pos': 0.036, 'compound': -0.1531}
#
# Title: Tata Motors joins hands with ESAF Small Finance Bank for vehicle finance
# Sentiment: {'neg': 0.0, 'neu': 0.964, 'pos': 0.036, 'compound': 0.1779}
#
# Title: Remembering Ratan Tata: His Automotive Legacy Will Remain Unparalleled In India
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Nano to JLR: Ratan Tata turned Tata Motors into a global auto powerhouse
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Ratan Tata was India's conscience keeper; this bull market was also led by Tata Group companies: Ramesh Damani
# Sentiment: {'neg': 0.0, 'neu': 0.814, 'pos': 0.186, 'compound': 0.8481}
#
# Title: Share Market Highlights 9th October 2024: Sensex closes at 81,634.81, Nifty closes at 25,013. Top gainers Tata Motors, Tech Mahindra
# Sentiment: {'neg': 0.0, 'neu': 0.797, 'pos': 0.203, 'compound': 0.9001}
#
# Title: How Ratan Tata transformed Tata Group — a timeline
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Tata Motors Sees 9% YoY Drop In Sales In Sept'24, Wholesales 41,313 Units
# Sentiment: {'neg': 0.075, 'neu': 0.925, 'pos': 0.0, 'compound': -0.2732}
#
# Title: Tata Capital, Tata Motors Finance merger receives RBI's approval
# Sentiment: {'neg': 0.0, 'neu': 0.814, 'pos': 0.186, 'compound': 0.743}
#
# Title: Tata Sons planning to buy an additional 13% stake in Tata Autocomp Systems
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Ratan Tata, former Tata Group chairman, dies at age 86
# Sentiment: {'neg': 0.224, 'neu': 0.776, 'pos': 0.0, 'compound': -0.6369}
#
# Title: Tata Motors JLR Q2 Update: Production slumps 7% to 86K units, retail sales down 3% to 1.03 lakh units
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Sensex, Nifty slump over 2 pc as Middle East conflict deepens
# Sentiment: {'neg': 0.218, 'neu': 0.596, 'pos': 0.187, 'compound': -0.296}
#
# Title: Ratan Tata's globe-spanning acquisitions: Corus Group, JLR, Air India, Tetley Tea, Daewoo Motors & more
# Sentiment: {'neg': 0.022, 'neu': 0.928, 'pos': 0.05, 'compound': 0.3239}
#
# Title: Tata Motors breaks ground to set up JLR manufacturing plant in TN
# Sentiment: {'neg': 0.08, 'neu': 0.92, 'pos': 0.0, 'compound': -0.4215}
#
# Title: Market Trading Guide: Tata Motors, JSW Infra among 5 stock recommendations for Tuesday
# Sentiment: {'neg': 0.0, 'neu': 0.922, 'pos': 0.078, 'compound': 0.5574}
#
# Title: Gainers & Losers: Reliance Industries, Tata Motors among 12 stocks in limelight on Monday
# Sentiment: {'neg': 0.074, 'neu': 0.868, 'pos': 0.059, 'compound': -0.1779}
#
# Title: Optimistic about Tata Motors, M&M, in no hurry to buy Ola Electric: Deven Choksey
# Sentiment: {'neg': 0.036, 'neu': 0.673, 'pos': 0.291, 'compound': 0.9261}
#
# Title: Tata Motors shares stuck in a circular track since February. Can they ditch bear's grip?
# Sentiment: {'neg': 0.107, 'neu': 0.819, 'pos': 0.074, 'compound': -0.25}
#
# Title: Hot Stocks: Brokerages on Trent, Nykaa, M&M, Tata Motors and Godrej Properties
# Sentiment: {'neg': 0.04, 'neu': 0.728, 'pos': 0.231, 'compound': 0.8957}
#
# Title: Hyundai IPO valuation: How it stacks against rivals Maruti Suzuki, M&M and Tata Motors
# Sentiment: {'neg': 0.031, 'neu': 0.893, 'pos': 0.076, 'compound': 0.4215}
#
# Title: Ratan Tata’s Legacy: 19 Tata stocks turn multibaggers with returns up to 2,830% in five years
# Sentiment: {'neg': 0.0, 'neu': 0.905, 'pos': 0.095, 'compound': 0.5719}
#
# Title: Diwali Car Discounts: Tata Motors Revised Starting Price On Select Models
# Sentiment: {'neg': 0.0, 'neu': 0.704, 'pos': 0.296, 'compound': 0.9118}
#
# Title: Ratan Tata over the years-II
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Ratan Tata, of India's Tata conglomerate, in hospital intensive care, sources say
# Sentiment: {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'compound': 0.7506}
#
# Title: Tetley Tea To BigBasket: Tata Group's Biggest Strides Under Ratan Tata
# Sentiment: {'neg': 0.054, 'neu': 0.894, 'pos': 0.052, 'compound': -0.0258}
#
# Title: Ratan Tata, el patriarca del mayor conglomerado indio Grupo Tata, fallece a los 86 años
# Sentiment: {'neg': 0.071, 'neu': 0.929, 'pos': 0.0, 'compound': -0.3818}
#
# Title: Updated Tata Punch launched at Rs 6.13 lakh: Larger infotainment display and more features!
# Sentiment: {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.3164}
#
# Title: Ratan Tata: The man who turned Tata Motors around
# Sentiment: {'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.6808}
#
# Title: JLR to transform Halewood plant into EV production unit at an outlay of £500 million
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Sensex, Nifty fall in early trade
# Sentiment: {'neg': 0.0, 'neu': 0.81, 'pos': 0.19, 'compound': 0.6597}
#
# Title: Tata Electronics to hire 20K more employees at Hosur unit: Chandrasekaran
# Sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# Title: Goodbye Jaguar I-Pace: Last drive in an EV game-changer
# Sentiment: {'neg': 0.042, 'neu': 0.931, 'pos': 0.027, 'compound': -0.2023}
#
# Title: Tata Group Stocks Rise Up To 10%
# Sentiment: {'neg': 0.0, 'neu': 0.929, 'pos': 0.071, 'compound': 0.296}
#
# Title: Ratan Tata, former chairman of Indian conglomerate Tata Sons, dies at age 86 in a Mumbai hospital
# Sentiment: {'neg': 0.196, 'neu': 0.804, 'pos': 0.0, 'compound': -0.9136}
#
# Title: TN Cabinet approves 14 projects bringing investment worth ₹38,699 crore
# Sentiment: {'neg': 0.0, 'neu': 0.611, 'pos': 0.389, 'compound': 0.9001}
#
# Title: Ratan Tata acquired Tetley, JLR en route to internationalize the group
# Sentiment: {'neg': 0.0, 'neu': 0.898, 'pos': 0.102, 'compound': 0.3818}
#
# Title: Nexon EV Fire Case: Court AsksTata Motors To Pay Rs 19.55 Lakh - Details
# Sentiment: {'neg': 0.167, 'neu': 0.768, 'pos': 0.066, 'compound': -0.3818}
#
# Title: When Stranger's Tata Indica Praise Brought "Joy" To Ratan Tata: Niira Radia
# Sentiment: {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'compound': 0.802}
#
# Title: "Same Legacy": Niira Radia As Noel Tata Succeeds Ratan Tata At Tata Trusts
# Sentiment: {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'compound': 0.9118}
#
# Title: The indomitable, fighting spirit of Ratan Tata
# Sentiment: {'neg': 0.115, 'neu': 0.773, 'pos': 0.112, 'compound': -0.0258}

# %%
import requests
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

# Download VADER for sentiment analysis
nltk.download('vader_lexicon')

# Your News API key
API_KEY = '94a44c5e22284be1aebbe334af0ac941'  # Replace with your actual News API key

# Function to fetch news articles based on company name
def fetch_news_articles(company_name):
    url = f'https://newsapi.org/v2/everything?q={company_name}&apiKey={API_KEY}'
    response = requests.get(url)
    if response.status_code == 200:
        articles = response.json().get('articles', [])
        return articles
    else:
        print(f"Error fetching news: {response.status_code}")
        return []

# Function to perform sentiment analysis
def analyze_sentiment(articles):
    sia = SentimentIntensityAnalyzer()
    sentiments = []

    for article in articles:
        title = article.get('title', '')
        description = article.get('description', '')
        content = (title + ' ' + description).strip()

        # Calculate sentiment scores
        sentiment = sia.polarity_scores(content)
        sentiments.append(sentiment)

    return sentiments

# Function to calculate average sentiment scores
def calculate_average_sentiment(sentiments):
    if not sentiments:
        return None

    avg_sentiment = {
        'neg': 0,
        'neu': 0,
        'pos': 0,
        'compound': 0
    }

    for sentiment in sentiments:
        avg_sentiment['neg'] += sentiment['neg']
        avg_sentiment['neu'] += sentiment['neu']
        avg_sentiment['pos'] += sentiment['pos']
        avg_sentiment['compound'] += sentiment['compound']

    num_sentiments = len(sentiments)
    avg_sentiment = {k: v / num_sentiments for k, v in avg_sentiment.items()}

    return avg_sentiment

# Main function
def main():
    company_name = input("Enter the company name (e.g., 'Apple', 'Google'): ").strip()

    # Fetch news articles
    articles = fetch_news_articles(company_name)

    if not articles:
        print("No articles found.")
        return

    # Perform sentiment analysis
    sentiment_results = analyze_sentiment(articles)

    print("\nSentiment Analysis Results:")
    for article in articles:
        title = article.get('title', '')
        print(f"Title: {title}\n")

    # Calculate average sentiment scores
    avg_sentiment = calculate_average_sentiment(sentiment_results)

    if avg_sentiment:
        print("\nAverage Sentiment Scores:")
        print(f"Negative: {avg_sentiment['neg']:.4f}")
        print(f"Neutral: {avg_sentiment['neu']:.4f}")
        print(f"Positive: {avg_sentiment['pos']:.4f}")
        print(f"Compound: {avg_sentiment['compound']:.4f}")

# Example usage
if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Enter the company name (e.g., 'Apple', 'Google'): Tata motors
#
# Sentiment Analysis Results:
# Title: Ratan Tata, former chairman of Indian conglomerate Tata Sons, dies at age 86 in a Mumbai hospital
#
# Title: Indian entrepreneur, industrialist, and philanthropist, Ratan Tata, dead at 86
#
# Title: India’s Ratan Tata, the man who knew how to ‘think big and bold’
#
# Title: Ratan Tata, ‘titan’ of Indian business, dies at 86
#
# Title: Ratan Tata: India’s Icon Of Business And Branding Genius Dies At 86
#
# Title: Ratan Tata—Ex-Leader Of India’s Massive Tata Group—Dies At 86
#
# Title: Tata motors chairman Ratan Tata dies aged 86
#
# Title: È morto Ratan Tata: capo del gruppo che controlla Jaguar Land Rover
#
# Title: Ratan Tata passes away at 86
#
# Title: Starbucks, Tetley, Jaguar Land Rover: Remembering Ratan Tata's global ambitions
#
# Title: Muere Ratan Tata, el visionario que encabezó la apertura de la economía india al mundo
#
# Title: Omul de afaceri indian Ratan Tata, creatorul celei mai ieftine mașini din lume, a murit la vârsta de 86 de ani
#
# Title: Ratan Tata, Indian magnate who built global empire, dead at 86
#
# Title: [Removed]
#
# Title: Jaguar Land Rover to invest £500m in car plant
#
# Title: Ratan Tata, who put India's Tata Group on global map, dies at 86
#
# Title: Ratan Tata, who put India’s Tata Group on the global map, dies at 86
#
# Title: BasiGo Flags Off New Tata Ultra Electric Buses In Nairobi, Strengthens Sustainable Public Transport In Kenya
#
# Title: [Removed]
#
# Title: What’s Driving The Son Of India’s Richest Woman To Pour Billions Into EVs?
#
# Title: Tata Motors Stocks/Share Price Live Updates: Tata Motors shares trade among top gainers in Nifty 50 pack
#
# Title: Tata Motors Stocks/Share Price Highlights October 9, 2024: Tata Motors shares end 2% higher among top gainers of Nifty 50 pack
#
# Title: Ratan Tata, former chairman of Indian conglomerate Tata Group, has died at age 86
#
# Title: Ratan Tata: Πέθανε σε ηλικία 86 ετών ο Ινδός κροίσος και πρόεδρος της ομώνυμης αυτοκινητοβιομηχανίας
#
# Title: Mukund G Rajan on Ratan Tata: A titan of our times who elevated India's stature
#
# Title: A murit fondatorul grupului Tata, cel mai modest mogul. Conducea un autoturism ieftin, deşi avea fabrici de maşini de lux
#
# Title: Hindistan'ın en ünlü iş insanı öldü
#
# Title: Ινδία: Πέθανε ο Ράταν Τάτα, ο πρώην πρόεδρος του ομίλου Tata – Είχε αγοράσει τη Jaguar και τη Land Rover
#
# Title: Tata Motors global wholesale declines by 11% in Q2FY25
#
# Title: Ratan Tata, who put India's Tata Group on the global map, dies at 86
#
# Title: Stalin lays foundation stone for Tata Motors' Rs 9,000 cr manufacturing plant in TN
#
# Title: Ratan Tata, Indian industry legend and business icon, dies aged 86
#
# Title: Ratan Tata on kuollut
#
# Title: Indian tycoon and former chairman of Tata Group dies
#
# Title: Neutral Tata Motors, target price Rs 990: Motilal Oswal Financial Services
#
# Title: Stock market update: Stocks that hit 52-week lows on NSE in today's trade
#
# Title: Tata’s next challenge: Leadership void at Trusts
#
# Title: Tata Motors, Tata Steel among 5 stocks with short buildup
#
# Title: Tata Motors honors Pimpri plant workers with Diwali bonuses amid Ratan Tata’s farewell
#
# Title: Terra Charge India、デリー政府とリライアンスグループの合弁電力事業社、BSESヤムナパワーリミテッドと業務提携開始
#
# Title: Stock market update: Stocks that hit 52-week lows on NSE
#
# Title: Tata Motors breaks ground for ₹9,000-cr high-end vehicle manufacturing unit in TN
#
# Title: How Ratan Tata acquired JLR from Ford, a decade after Ford rejected an offer to buy Tata Motors
#
# Title: Miliardarul indian Ratan Tata a murit la vârsta de 86 de ani. A fost președintele Grupului Tata, cu venituri de 100 de miliarde anual
#
# Title: Nie żyje jeden z najbogatszych ludzi świata. Stworzył marki, które zatrudniają ponad 660 tys. pracowników
#
# Title: Tata Sons Chairman shares touching tribute to late Ratan Tata
#
# Title: El magnate indio Ratan Tata fallece a los 86 años
#
# Title: Tata Steel Stocks / Tata Steel Share Price Highlights September 25, 2024: Tata Steel shares trade above ₹160 mark
#
# Title: Addio a Ratan Tata, l'ex presidente del gruppo automobilistico
#
# Title: Tata Group forms alliance with Analog Devices for semiconductor manufacturing
#
# Title: Ratan Tata over the years - I
#
# Title: Hot stocks: Brokerages on Tata Motors, FirstCry and Exide
#
# Title: Stock market update: Stocks that hit 52-week lows on NSE in today's trade
#
# Title: Ratan Tata years: Profit zoomed 51 times, market capitalization 33 times under his leadership
#
# Title: The titan who rebuilt Tata: Ratan Tata was as much about cleaning up the group as he was about taking it to new scales
#
# Title: Hyundai India's record $3.3 billion IPO subscribed 18% on first day of bidding
#
# Title: Ratan Tata, former Tata Group chairman, dies at age 86
#
# Title: Ratan Tata’s clarion call to ‘go global’
#
# Title: Emkay Global sees Tata Motors stock rising with healthier balance sheet and valuation
#
# Title: Remembering Ratan Tata and cars close to his heart beyond the Nano
#
# Title: Tata Motors joins hands with ESAF Small Finance Bank for vehicle finance
#
# Title: Remembering Ratan Tata: His Automotive Legacy Will Remain Unparalleled In India
#
# Title: Nano to JLR: Ratan Tata turned Tata Motors into a global auto powerhouse
#
# Title: Ratan Tata was India's conscience keeper; this bull market was also led by Tata Group companies: Ramesh Damani
#
# Title: Share Market Highlights 9th October 2024: Sensex closes at 81,634.81, Nifty closes at 25,013. Top gainers Tata Motors, Tech Mahindra
#
# Title: How Ratan Tata transformed Tata Group — a timeline
#
# Title: Tata Motors Sees 9% YoY Drop In Sales In Sept'24, Wholesales 41,313 Units
#
# Title: Tata Capital, Tata Motors Finance merger receives RBI's approval
#
# Title: Tata Sons planning to buy an additional 13% stake in Tata Autocomp Systems
#
# Title: Ratan Tata, former Tata Group chairman, dies at age 86
#
# Title: Tata Motors JLR Q2 Update: Production slumps 7% to 86K units, retail sales down 3% to 1.03 lakh units
#
# Title: Sensex, Nifty slump over 2 pc as Middle East conflict deepens
#
# Title: Ratan Tata's globe-spanning acquisitions: Corus Group, JLR, Air India, Tetley Tea, Daewoo Motors & more
#
# Title: Tata Motors breaks ground to set up JLR manufacturing plant in TN
#
# Title: Market Trading Guide: Tata Motors, JSW Infra among 5 stock recommendations for Tuesday
#
# Title: Gainers & Losers: Reliance Industries, Tata Motors among 12 stocks in limelight on Monday
#
# Title: Optimistic about Tata Motors, M&M, in no hurry to buy Ola Electric: Deven Choksey
#
# Title: Tata Motors shares stuck in a circular track since February. Can they ditch bear's grip?
#
# Title: Hot Stocks: Brokerages on Trent, Nykaa, M&M, Tata Motors and Godrej Properties
#
# Title: Hyundai IPO valuation: How it stacks against rivals Maruti Suzuki, M&M and Tata Motors
#
# Title: Ratan Tata’s Legacy: 19 Tata stocks turn multibaggers with returns up to 2,830% in five years
#
# Title: Diwali Car Discounts: Tata Motors Revised Starting Price On Select Models
#
# Title: Ratan Tata over the years-II
#
# Title: Ratan Tata, of India's Tata conglomerate, in hospital intensive care, sources say
#
# Title: Tetley Tea To BigBasket: Tata Group's Biggest Strides Under Ratan Tata
#
# Title: Ratan Tata, el patriarca del mayor conglomerado indio Grupo Tata, fallece a los 86 años
#
# Title: Updated Tata Punch launched at Rs 6.13 lakh: Larger infotainment display and more features!
#
# Title: Ratan Tata: The man who turned Tata Motors around
#
# Title: JLR to transform Halewood plant into EV production unit at an outlay of £500 million
#
# Title: Sensex, Nifty fall in early trade
#
# Title: Tata Electronics to hire 20K more employees at Hosur unit: Chandrasekaran
#
# Title: Goodbye Jaguar I-Pace: Last drive in an EV game-changer
#
# Title: Tata Group Stocks Rise Up To 10%
#
# Title: Ratan Tata, former chairman of Indian conglomerate Tata Sons, dies at age 86 in a Mumbai hospital
#
# Title: TN Cabinet approves 14 projects bringing investment worth ₹38,699 crore
#
# Title: Ratan Tata acquired Tetley, JLR en route to internationalize the group
#
# Title: Nexon EV Fire Case: Court AsksTata Motors To Pay Rs 19.55 Lakh - Details
#
# Title: When Stranger's Tata Indica Praise Brought "Joy" To Ratan Tata: Niira Radia
#
# Title: "Same Legacy": Niira Radia As Noel Tata Succeeds Ratan Tata At Tata Trusts
#
# Title: The indomitable, fighting spirit of Ratan Tata
#
#
# Average Sentiment Scores:
# Negative: 0.0557
# Neutral: 0.8675
# Positive: 0.0769
# Compound: 0.0854

# %%
import requests
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

# Download VADER for sentiment analysis
nltk.download('vader_lexicon')

# Your News API key
API_KEY = '94a44c5e22284be1aebbe334af0ac941'  # Replace with your actual News API key

# Function to fetch top business headlines from India
def fetch_business_headlines():
    url = f'https://newsapi.org/v2/top-headlines?country=in&category=business&apiKey={API_KEY}'
    response = requests.get(url)
    if response.status_code == 200:
        articles = response.json().get('articles', [])
        return articles
    else:
        print(f"Error fetching news: {response.status_code}")
        return []

# Function to perform sentiment analysis
def analyze_sentiment(articles):
    sia = SentimentIntensityAnalyzer()
    sentiments = []
    for article in articles:
        title = article.get('title', '')
        description = article.get('description', '')

        # Ensure both title and description are strings
        content = (title if title else '') + ' ' + (description if description else '')
        sentiment = sia.polarity_scores(content)
        sentiments.append((title, sentiment))
    return sentiments

# Main function
def main():
    # Fetch business headlines
    articles = fetch_business_headlines()

    if not articles:
        print("No articles found.")
        return

    # Perform sentiment analysis
    sentiment_results = analyze_sentiment(articles)

    print("\nSentiment Analysis Results:")
    for title, sentiment in sentiment_results:
        print(f"Title: {title}\nSentiment: {sentiment}\n")

# Example usage
if __name__ == "__main__":
    main()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# No articles found.
